# %% [markdown]
# # Import the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('Covid_Dataset.csv')

# %%
# display the rows

df.head(10)
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03-05-2020        3          1
# 1      2             1    2             1  03-06-2020        3          1
# 2      2             1    2             2  09-06-2020        1          2
# 3      2             1    1             1  12-06-2020        3          2
# 4      2             1    2             1  21-06-2020        3          2
# 5      2             1    1             2  9999-99-99        2          1
# 6      2             1    1             1  9999-99-99        3          2
# 7      2             1    1             1  9999-99-99        3          1
# 8      2             1    1             2  9999-99-99        2          2
# 9      2             1    1             2  9999-99-99        2          2
#
#    AGE  PREGNANT  DIABETES  COPD  ASTHMA  INMSUPR  HIPERTENSION  \
# 0   65         2         0     0       0        0             1
# ...

# %% [markdown]
# # Data Exploration and Cleaning

# %%
# get the shape of data

print("The number of rows : ", df.shape[0])
print("The number of columns : ", df.shape[1])
# Out:
# The number of rows :  199999
# The number of columns :  21

# %%
#  summerize the data

df.describe(include = 'all').T
# Out:
#                          count unique         top    freq       mean  \
# USMER                 199999.0    NaN         NaN     NaN   1.560453
# MEDICAL_UNIT          199999.0    NaN         NaN     NaN    3.90017
# SEX                   199999.0    NaN         NaN     NaN   1.523433
# PATIENT_TYPE          199999.0    NaN         NaN     NaN   1.346587
# DATE_DIED               199999    337  9999-99-99  158592        NaN
# INTUBED               199999.0    NaN         NaN     NaN   2.578108
# PNEUMONIA             199999.0    NaN         NaN     NaN   4.095105
# AGE                   199999.0    NaN         NaN     NaN  45.317002
# PREGNANT              199999.0    NaN         NaN     NaN   2.518763
# DIABETES              199999.0    NaN         NaN     NaN   0.172966
# COPD                  199999.0    NaN         NaN     NaN   0.021925
# ASTHMA                199999.0    NaN         NaN     NaN   0.031865
# INMSUPR               199999.0    NaN         NaN     NaN   0.018795
# ...

# %%
# identify missing value

df.isnull().sum()
# Out:
# USMER                   0
# MEDICAL_UNIT            0
# SEX                     0
# PATIENT_TYPE            0
# DATE_DIED               0
# INTUBED                 0
# PNEUMONIA               0
# AGE                     0
# PREGNANT                0
# DIABETES                0
# COPD                    0
# ASTHMA                  0
# INMSUPR                 0
# HIPERTENSION            0
# OTHER_DISEASE           0
# CARDIOVASCULAR          0
# OBESITY                 0
# RENAL_CHRONIC           0
# TOBACCO                 0
# CLASIFFICATION_FINAL    0
# ICU                     0
# dtype: int64

# %%
# get the information of data

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199999 entries, 0 to 199998
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   USMER                 199999 non-null  int64
#  1   MEDICAL_UNIT          199999 non-null  int64
#  2   SEX                   199999 non-null  int64
#  3   PATIENT_TYPE          199999 non-null  int64
#  4   DATE_DIED             199999 non-null  object
#  5   INTUBED               199999 non-null  int64
#  6   PNEUMONIA             199999 non-null  int64
#  7   AGE                   199999 non-null  int64
#  8   PREGNANT              199999 non-null  int64
#  9   DIABETES              199999 non-null  int64
#  10  COPD                  199999 non-null  int64
#  11  ASTHMA                199999 non-null  int64
#  12  INMSUPR               199999 non-null  int64
#  13  HIPERTENSION          199999 non-null  int64
# ...

# %%
# check the duplicated values

print('The duplicated rows are : ',df.duplicated().sum())
# Out:
# The duplicated rows are :  125590

# %%
# We have to drop these duplicated rows

df.drop_duplicates(inplace = True)

# %%
# Now again check the duplicated values

print('The duplicated rows are : ',df.duplicated().sum())
# Out:
# The duplicated rows are :  0

# %%
# after removing the duplicated rows, the shape of data will be :

df.shape
# Out:
# (74409, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74409 entries, 0 to 199996
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   USMER                 74409 non-null  int64
#  1   MEDICAL_UNIT          74409 non-null  int64
#  2   SEX                   74409 non-null  int64
#  3   PATIENT_TYPE          74409 non-null  int64
#  4   DATE_DIED             74409 non-null  object
#  5   INTUBED               74409 non-null  int64
#  6   PNEUMONIA             74409 non-null  int64
#  7   AGE                   74409 non-null  int64
#  8   PREGNANT              74409 non-null  int64
#  9   DIABETES              74409 non-null  int64
#  10  COPD                  74409 non-null  int64
#  11  ASTHMA                74409 non-null  int64
#  12  INMSUPR               74409 non-null  int64
#  13  HIPERTENSION          74409 non-null  int64
#  14  OTHER_DISEASE         74409 non-null  int64
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Box PLot

# %%
plt.figure(figsize=(15, 10))

numerical_columns = ['SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 'PREGNANT', 
                        'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION', 
                        'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC', 
                        'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU']
for i, column in enumerate(numerical_columns):
    plt.subplot(4, 5, i + 1)
    sns.boxplot(x=df[column])
    plt.title(column)
plt.tight_layout()
plt.savefig('outlier.png')
plt.show()

# %% [markdown]
# # Bar Plot

# %%
# Create a dictionary of categorical columns and their corresponding labels
categorical_columns = ['SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 'PREGNANT', 
                        'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION', 
                        'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC', 
                        'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU']

# Bar charts for each categorical feature
plt.figure(figsize=(15, 20))
for i, column in enumerate(categorical_columns):
    plt.subplot(6, 3, i + 1)
    df[column].value_counts().plot(kind='bar')
    plt.title(column)
    plt.xlabel('Category')
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Pie Plot

# %%
# Assuming df is your DataFrame and categorical_columns is defined
categorical_columns = ['SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 'PREGNANT', 
                        'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 'HIPERTENSION', 
                        'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 'RENAL_CHRONIC', 
                        'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU']

# Plot pie charts
fig, axes = plt.subplots(nrows=6, ncols=3, figsize=(18, 24))  # Adjust size as needed
fig.suptitle('Distribution of Categorical Features', fontsize=20)
axes = axes.flatten()  # Flatten the 2D array of axes to easily iterate

for i, column in enumerate(categorical_columns):
    ax = axes[i]
    df[column].value_counts().plot(kind='pie', autopct='%1.1f%%', ax=ax)
    ax.set_title(column, fontsize=12)
    ax.set_ylabel('')  # Hide y-axis label for pie charts
    ax.set_xlabel('')  # Hide x-axis label for pie charts

# Remove any empty subplots if there are more subplots than features
for j in range(len(categorical_columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust the rectangle to make room for the suptitle
plt.show()

# %% [markdown]
# # HeatMap

# %%
# Compute correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Generate heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# # Histogram

# %%
# Assuming df is your DataFrame
numerical_columns = ['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA', 
                      'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR', 
                      'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY', 
                      'RENAL_CHRONIC', 'TOBACCO', 'CLASIFFICATION_FINAL', 'ICU']

# Plot histograms
fig, axes = plt.subplots(nrows=5, ncols=4, figsize=(20, 20))  # Adjust size as needed
fig.suptitle('Histograms of Numerical Features', fontsize=20)
axes = axes.flatten()  # Flatten the 2D array of axes to easily iterate

for i, column in enumerate(numerical_columns):
    df[column].hist(ax=axes[i],bins=5)
    axes[i].set_title(column, fontsize=12)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# Remove any empty subplots if there are more subplots than features
for j in range(len(numerical_columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust the rectangle to make room for the suptitle
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd

# Convert the 'DATE_DIED' column to datetime format and specify the expected formats
df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'], format='%d-%m-%Y', errors='coerce')

# Now, convert it back to string format in 'YYYY-MM-DD'
df['DATE_DIED'] = df['DATE_DIED'].dt.strftime('%Y-%m-%d')

# Check if the column is now normalized
print(df['DATE_DIED'].head())
# Out:
# 0    2020-05-03
# 1    2020-06-03
# 2    2020-06-09
# 3    2020-06-12
# 4    2020-06-21
# Name: DATE_DIED, dtype: object

# %%
df['DATE_DIED'].unique()
# Out:
# array(['2020-05-03', '2020-06-03', '2020-06-09', '2020-06-12',
#        '2020-06-21', nan, '2020-02-26', '2020-04-05', '2020-05-08',
#        '2020-05-20', '2020-07-17', '2020-01-13', '2020-01-22',
#        '2020-01-29', '2020-02-13', '2020-02-18', '2020-02-19',
#        '2020-02-20', '2020-02-24', '2020-03-04', '2020-03-07',
#        '2020-03-12', '2020-03-14', '2020-03-18', '2020-03-27',
#        '2020-03-28', '2020-03-29', '2020-04-02', '2020-04-06',
#        '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-10',
#        '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14',
#        '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18',
#        '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23',
#        '2020-04-24', '2020-04-25', '2020-04-26', '2020-04-27',
#        '2020-04-28', '2020-04-29', '2020-04-30', '2020-05-01',
#        '2020-05-02', '2020-05-04', '2020-05-05', '2020-05-06',
#        '2020-05-07', '2020-05-09', '2020-05-10', '2020-05-11',
# ...

# %%
df['DATE_DIED'].isnull().sum()
# Out:
# np.int64(33607)

# %%
df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74409 entries, 0 to 199996
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   USMER                 74409 non-null  int64
#  1   MEDICAL_UNIT          74409 non-null  int64
#  2   SEX                   74409 non-null  int64
#  3   PATIENT_TYPE          74409 non-null  int64
#  4   DATE_DIED             40802 non-null  datetime64[ns]
#  5   INTUBED               74409 non-null  int64
#  6   PNEUMONIA             74409 non-null  int64
#  7   AGE                   74409 non-null  int64
#  8   PREGNANT              74409 non-null  int64
#  9   DIABETES              74409 non-null  int64
#  10  COPD                  74409 non-null  int64
#  11  ASTHMA                74409 non-null  int64
#  12  INMSUPR               74409 non-null  int64
#  13  HIPERTENSION          74409 non-null  int64
#  14  OTHER_DISEASE         74409 non-null  int64
# ...

# %%
import pandas as pd

# Convert the 'DATE_DIED' column to datetime format and specify the expected formats
df['DATE_DIED'] = pd.to_datetime(df['DATE_DIED'], format='%d-%m-%Y', errors='coerce')

# Now, convert it back to string format in 'YYYY-MM-DD'
df['DATE_DIED'] = df['DATE_DIED'].dt.strftime('%Y-%m-%d')

# Check if the column is now normalized
df['DATE_DIED'].head()
# Out:
# 0    2020-05-03
# 1    2020-06-03
# 2    2020-06-09
# 3    2020-06-12
# 4    2020-06-21
# Name: DATE_DIED, dtype: object

# %% [markdown]
# # Model Building

# %%
# Import necessary libraries

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, f1_score


# List of feature columns and target column
features = ['USMER', 'MEDICAL_UNIT', 'SEX', 'PATIENT_TYPE', 'INTUBED', 'PNEUMONIA',
            'AGE', 'PREGNANT', 'DIABETES', 'COPD', 'ASTHMA', 'INMSUPR',
            'HIPERTENSION', 'OTHER_DISEASE', 'CARDIOVASCULAR', 'OBESITY',
            'RENAL_CHRONIC', 'TOBACCO', 'ICU']
target = 'CLASIFFICATION_FINAL'

# Split the data into features and target
X = df[features]
y = df[target]

# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train a logistic regression model
logistic_model = LogisticRegression()
logistic_model.fit(X_train, y_train)

# Predict and evaluate logistic regression model
y_pred_logistic = logistic_model.predict(X_test)
accuracy_logistic = accuracy_score(y_test, y_pred_logistic)
f1_logistic = f1_score(y_test, y_pred_logistic, average='weighted')

print(f"Logistic Regression Accuracy: {accuracy_logistic:.4f}")
print(f"Logistic Regression F1 Score: {f1_logistic:.4f}")

# Experiment with Decision Tree Classifier
tree_model = DecisionTreeClassifier()
tree_model.fit(X_train, y_train)
y_pred_tree = tree_model.predict(X_test)
accuracy_tree = accuracy_score(y_test, y_pred_tree)
f1_tree = f1_score(y_test, y_pred_tree, average='weighted')

print(f"Decision Tree Accuracy: {accuracy_tree:.4f}")
print(f"Decision Tree F1 Score: {f1_tree:.4f}")

# Experiment with Random Forest Classifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

print(f"Random Forest Accuracy: {accuracy_rf:.4f}")
print(f"Random Forest F1 Score: {f1_rf:.4f}")

# Experiment with K-Nearest Neighbors Classifier
knn_model = KNeighborsClassifier()
knn_model.fit(X_train, y_train)
y_pred_knn = knn_model.predict(X_test)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
f1_knn = f1_score(y_test, y_pred_knn, average='weighted')

print(f"K-Nearest Neighbors Accuracy: {accuracy_knn:.4f}")
print(f"K-Nearest Neighbors F1 Score: {f1_knn:.4f}")

# Compare performance
print("\nModel Comparison:")
print(f"Logistic Regression: Accuracy = {accuracy_logistic:.4f}, F1 Score = {f1_logistic:.4f}")
print(f"Decision Tree: Accuracy = {accuracy_tree:.4f}, F1 Score = {f1_tree:.4f}")
print(f"Random Forest: Accuracy = {accuracy_rf:.4f}, F1 Score = {f1_rf:.4f}")
print(f"K-Nearest Neighbors: Accuracy = {accuracy_knn:.4f}, F1 Score = {f1_knn:.4f}")
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.6449
# Logistic Regression F1 Score: 0.5379
# Decision Tree Accuracy: 0.5121
# Decision Tree F1 Score: 0.4841
# Random Forest Accuracy: 0.5325
# Random Forest F1 Score: 0.5008
# K-Nearest Neighbors Accuracy: 0.5970
# K-Nearest Neighbors F1 Score: 0.5346
#
# Model Comparison:
# Logistic Regression: Accuracy = 0.6449, F1 Score = 0.5379
# Decision Tree: Accuracy = 0.5121, F1 Score = 0.4841
# ...

# %% [markdown]
# # Hyperparameter Model Tuning

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import uniform, randint

# Define hyperparameter grids with wider ranges for more exploration
logistic_param_dist = {
    'C': uniform(0.01, 10),  # Regularization strength
    'penalty': ['l1', 'l2'],  # Regularization type
    'solver': ['liblinear', 'saga']  # Solvers that support 'l1' penalty
}
tree_param_dist = {
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(5, 30),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_features': ['auto', 'sqrt', 'log2']
}
knn_param_dist = {
    'n_neighbors': randint(5, 20),
    'weights': ['uniform', 'distance'],
    'p': [1, 2],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# Perform RandomizedSearchCV for Logistic Regression
logistic_random_search = RandomizedSearchCV(LogisticRegression(max_iter=1000), logistic_param_dist,
                                            n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
logistic_random_search.fit(X_train, y_train)
best_logistic_model = logistic_random_search.best_estimator_

# Perform RandomizedSearchCV for Decision Tree
tree_random_search = RandomizedSearchCV(DecisionTreeClassifier(), tree_param_dist,
                                         n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
tree_random_search.fit(X_train, y_train)
best_tree_model = tree_random_search.best_estimator_

# Perform RandomizedSearchCV for K-Nearest Neighbors
knn_random_search = RandomizedSearchCV(KNeighborsClassifier(), knn_param_dist,
                                       n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42)
knn_random_search.fit(X_train, y_train)
best_knn_model = knn_random_search.best_estimator_

# Evaluate tuned models
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    return accuracy, f1

# Logistic Regression
accuracy_logistic, f1_logistic = evaluate_model(best_logistic_model, X_test, y_test)
print(f"Tuned Logistic Regression Accuracy: {accuracy_logistic:.4f}")
print(f"Tuned Logistic Regression F1 Score: {f1_logistic:.4f}")

# Decision Tree
accuracy_tree, f1_tree = evaluate_model(best_tree_model, X_test, y_test)
print(f"Tuned Decision Tree Accuracy: {accuracy_tree:.4f}")
print(f"Tuned Decision Tree F1 Score: {f1_tree:.4f}")

# K-Nearest Neighbors
accuracy_knn, f1_knn = evaluate_model(best_knn_model, X_test, y_test)
print(f"Tuned K-Nearest Neighbors Accuracy: {accuracy_knn:.4f}")
print(f"Tuned K-Nearest Neighbors F1 Score: {f1_knn:.4f}")
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from scipy.stats import uniform, randint

# Define hyperparameter grids with corrected parameters
logistic_param_dist = {
    'C': uniform(0.01, 10),  # Regularization strength
    'penalty': ['l1', 'l2'],  # Regularization type
    'solver': ['liblinear', 'saga']  # Solvers that support 'l1' penalty
}
tree_param_dist = {
    'criterion': ['gini', 'entropy'],
    'max_depth': randint(5, 30),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'max_features': ['sqrt', 'log2', None]  # Removed 'auto'
}
knn_param_dist = {
    'n_neighbors': randint(5, 20),
    'weights': ['uniform', 'distance'],
    'p': [1, 2],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

# Perform RandomizedSearchCV for Logistic Regression
logistic_random_search = RandomizedSearchCV(LogisticRegression(max_iter=1000), logistic_param_dist,
                                            n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42, error_score='raise')
logistic_random_search.fit(X_train, y_train)
best_logistic_model = logistic_random_search.best_estimator_

# Perform RandomizedSearchCV for Decision Tree
tree_random_search = RandomizedSearchCV(DecisionTreeClassifier(), tree_param_dist,
                                         n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42, error_score='raise')
tree_random_search.fit(X_train, y_train)
best_tree_model = tree_random_search.best_estimator_

# Perform RandomizedSearchCV for K-Nearest Neighbors
knn_random_search = RandomizedSearchCV(KNeighborsClassifier(), knn_param_dist,
                                       n_iter=20, cv=5, scoring='accuracy', n_jobs=-1, random_state=42, error_score='raise')
knn_random_search.fit(X_train, y_train)
best_knn_model = knn_random_search.best_estimator_

# Evaluate tuned models
def evaluate_model(model, X_test, y_test):
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average='weighted')
    return accuracy, f1

# Logistic Regression
accuracy_logistic, f1_logistic = evaluate_model(best_logistic_model, X_test, y_test)
print(f"Tuned Logistic Regression Accuracy: {accuracy_logistic:.4f}")
print(f"Tuned Logistic Regression F1 Score: {f1_logistic:.4f}")

# Decision Tree
accuracy_tree, f1_tree = evaluate_model(best_tree_model, X_test, y_test)
print(f"Tuned Decision Tree Accuracy: {accuracy_tree:.4f}")
print(f"Tuned Decision Tree F1 Score: {f1_tree:.4f}")

# K-Nearest Neighbors
accuracy_knn, f1_knn = evaluate_model(best_knn_model, X_test, y_test)
print(f"Tuned K-Nearest Neighbors Accuracy: {accuracy_knn:.4f}")
print(f"Tuned K-Nearest Neighbors F1 Score: {f1_knn:.4f}")
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:349: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...
